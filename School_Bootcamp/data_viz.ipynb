# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("data/pro_data.xlsx")

# %%
df.head()
# Out:
#    student_id       name  class section  english  maths  statistics  python  \
# 0      100001  Student_1      8       C     83.0   72.0        92.0    47.0
# 1      100002  Student_2      9       C     59.0   75.0        67.0    46.0
# 2      100003  Student_3     10       A     76.0   81.0        74.0    54.0
# 3      100004  Student_4      8       A     57.0   62.0        73.0   100.0
# 4      100005  Student_5      9       B     91.0   70.0        54.0    66.0
#
#    attendance  avg_marks result grade attendence_lvl  risk_flag weak_subject
# 0   84.000000      73.50   Pass     B           Good          0       python
# 1   76.000000      61.75   Pass     B           Good          0       python
# 2   82.000000      71.25   Pass     B           Good          0       python
# 3   78.000000      73.00   Pass     B           Good          0      english
# 4   84.181266      70.25   Pass     B           Good          0   statistics

# %%
avg_marks=sns.histplot(df['avg_marks'],bins=20,kde=True)
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Number of Students")
# Out:
# Text(0, 0.5, 'Number of Students')
